# %%
    # If the city is unique, then we will add it to the cities list.
# Import dependecies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
# Create a set of 2000 random latitude and long combo
lats = np.random.uniform(low=-90.000, high = 90.000, size=2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)

lat_lngs=zip(lats,lngs)
lat_lngs

# %%
# Create a list for holding the cities.
coordinates = list(lat_lngs)
# Creating a list to hold the cities
cities = []
# # Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city coutn to confirm sufficient count
len(cities)
# Out:
# 749

# %%
# Importing the dependencies
import requests
from config import api_key
from datetime import datetime

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | hithadhoo
# Processing Record 5 of Set 1 | cidreira
# Processing Record 6 of Set 1 | longyearbyen
# Processing Record 7 of Set 1 | adrar
# Processing Record 8 of Set 1 | cabedelo
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 1 | isangel
# Processing Record 13 of Set 1 | quzhou
# Processing Record 14 of Set 1 | kambove
# Processing Record 15 of Set 1 | norman wells
# Processing Record 16 of Set 1 | saint-philippe
# Processing Record 17 of Set 1 | lethem
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | benguela
# Processing Record 20 of Set 1 | la libertad
# Processing Record 21 of Set 1 | khani
# Processing Record 22 of Set 1 | san joaquin
# Processing Record 23 of Set 1 | henties bay
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | kapaa
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | butaritari
# Processing Record 28 of Set 1 | kiruna
# Processing Record 29 of Set 1 | stara zagora
# Processing Record 30 of Set 1 | saint george
# Processing Record 31 of Set 1 | pangoa
# Processing Record 32 of Set 1 | lagoa
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 1 | faya
# Processing Record 36 of Set 1 | luba
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | georgetown
# Processing Record 39 of Set 1 | east london
# Processing Record 40 of Set 1 | kruisfontein
# Processing Record 41 of Set 1 | letlhakane
# Processing Record 42 of Set 1 | mataura
# Processing Record 43 of Set 1 | kupang
# Processing Record 44 of Set 1 | hasaki
# Processing Record 45 of Set 1 | clyde river
# Processing Record 46 of Set 1 | meulaboh
# Processing Record 47 of Set 1 | hambantota
# Processing Record 48 of Set 1 | bethel
# Processing Record 49 of Set 1 | vaideeni
# Processing Record 50 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 1 of Set 2 | haines junction
# Processing Record 2 of Set 2 | lebu
# Processing Record 3 of Set 2 | naguilian
# Processing Record 4 of Set 2 | isla vista
# Processing Record 5 of Set 2 | pemangkat
# Processing Record 6 of Set 2 | walvis bay
# Processing Record 7 of Set 2 | ituni
# City not found. Skipping...
# Processing Record 8 of Set 2 | formosa
# Processing Record 9 of Set 2 | bollnas
# Processing Record 10 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 2 | misratah
# Processing Record 12 of Set 2 | penticton
# Processing Record 13 of Set 2 | punta arenas
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | lere
# Processing Record 16 of Set 2 | yushala
# Processing Record 17 of Set 2 | inongo
# Processing Record 18 of Set 2 | pevek
# Processing Record 19 of Set 2 | waingapu
# Processing Record 20 of Set 2 | vuktyl
# Processing Record 21 of Set 2 | mahebourg
# Processing Record 22 of Set 2 | busselton
# Processing Record 23 of Set 2 | oranjemund
# Processing Record 24 of Set 2 | oktyabrskoye
# Processing Record 25 of Set 2 | port lincoln
# Processing Record 26 of Set 2 | okha
# Processing Record 27 of Set 2 | usinsk
# Processing Record 28 of Set 2 | san jose
# Processing Record 29 of Set 2 | cabo san lucas
# Processing Record 30 of Set 2 | ixtapa
# Processing Record 31 of Set 2 | arraial do cabo
# Processing Record 32 of Set 2 | macusani
# Processing Record 33 of Set 2 | cherskiy
# Processing Record 34 of Set 2 | dovbysh
# Processing Record 35 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 2 | obo
# Processing Record 37 of Set 2 | cap malheureux
# Processing Record 38 of Set 2 | devonport
# Processing Record 39 of Set 2 | cape canaveral
# Processing Record 40 of Set 2 | sale
# Processing Record 41 of Set 2 | hermanus
# Processing Record 42 of Set 2 | fortuna
# Processing Record 43 of Set 2 | tasiilaq
# Processing Record 44 of Set 2 | salalah
# Processing Record 45 of Set 2 | torbay
# Processing Record 46 of Set 2 | qaanaaq
# Processing Record 47 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 2 | saurimo
# Processing Record 49 of Set 2 | aguie
# Processing Record 50 of Set 2 | lompoc
# Processing Record 1 of Set 3 | bambous virieux
# Processing Record 2 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 3 | hobyo
# Processing Record 4 of Set 3 | loukhi
# Processing Record 5 of Set 3 | scottsburgh
# City not found. Skipping...
# Processing Record 6 of Set 3 | rikitea
# Processing Record 7 of Set 3 | kodiak
# Processing Record 8 of Set 3 | sola
# Processing Record 9 of Set 3 | khatanga
# Processing Record 10 of Set 3 | castro
# Processing Record 11 of Set 3 | port moresby
# Processing Record 12 of Set 3 | bluff
# Processing Record 13 of Set 3 | mar del plata
# Processing Record 14 of Set 3 | katsuura
# Processing Record 15 of Set 3 | cockburn harbour
# City not found. Skipping...
# Processing Record 16 of Set 3 | sulangan
# Processing Record 17 of Set 3 | yei
# Processing Record 18 of Set 3 | moron
# Processing Record 19 of Set 3 | portland
# Processing Record 20 of Set 3 | dingle
# Processing Record 21 of Set 3 | ilulissat
# Processing Record 22 of Set 3 | hachinohe
# Processing Record 23 of Set 3 | namatanai
# Processing Record 24 of Set 3 | leshukonskoye
# Processing Record 25 of Set 3 | victoria
# Processing Record 26 of Set 3 | murovani kurylivtsi
# Processing Record 27 of Set 3 | cap-aux-meules
# Processing Record 28 of Set 3 | port elizabeth
# Processing Record 29 of Set 3 | ust-omchug
# Processing Record 30 of Set 3 | nikolskoye
# Processing Record 31 of Set 3 | mangan
# Processing Record 32 of Set 3 | yiyang
# Processing Record 33 of Set 3 | sigli
# Processing Record 34 of Set 3 | chuy
# Processing Record 35 of Set 3 | port alfred
# Processing Record 36 of Set 3 | makhinjauri
# Processing Record 37 of Set 3 | san juan
# Processing Record 38 of Set 3 | muravlenko
# Processing Record 39 of Set 3 | severo-kurilsk
# Processing Record 40 of Set 3 | pisco
# Processing Record 41 of Set 3 | kalasin
# Processing Record 42 of Set 3 | beringovskiy
# Processing Record 43 of Set 3 | aykhal
# Processing Record 44 of Set 3 | verkhnevilyuysk
# Processing Record 45 of Set 3 | owo
# Processing Record 46 of Set 3 | airai
# Processing Record 47 of Set 3 | pilar
# Processing Record 48 of Set 3 | carson city
# Processing Record 49 of Set 3 | vila franca do campo
# Processing Record 50 of Set 3 | kidal
# Processing Record 1 of Set 4 | ouargaye
# Processing Record 2 of Set 4 | ler
# Processing Record 3 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 4 of Set 4 | jablah
# Processing Record 5 of Set 4 | zeya
# Processing Record 6 of Set 4 | tommot
# Processing Record 7 of Set 4 | nemuro
# Processing Record 8 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 9 of Set 4 | maniitsoq
# Processing Record 10 of Set 4 | la asuncion
# Processing Record 11 of Set 4 | golspie
# Processing Record 12 of Set 4 | sitka
# Processing Record 13 of Set 4 | hilo
# Processing Record 14 of Set 4 | rabak
# Processing Record 15 of Set 4 | thompson
# Processing Record 16 of Set 4 | geraldton
# Processing Record 17 of Set 4 | saskylakh
# Processing Record 18 of Set 4 | puerto madryn
# Processing Record 19 of Set 4 | ribeira grande
# Processing Record 20 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 4 | leua
# Processing Record 22 of Set 4 | yumen
# Processing Record 23 of Set 4 | leningradskiy
# Processing Record 24 of Set 4 | beypur
# City not found. Skipping...
# Processing Record 25 of Set 4 | padang
# Processing Record 26 of Set 4 | buchanan
# Processing Record 27 of Set 4 | marsa matruh
# Processing Record 28 of Set 4 | kavaratti
# Processing Record 29 of Set 4 | sur
# Processing Record 30 of Set 4 | santa fe
# Processing Record 31 of Set 4 | bathsheba
# Processing Record 32 of Set 4 | mayor pablo lagerenza
# Processing Record 33 of Set 4 | kinkala
# Processing Record 34 of Set 4 | grojec
# Processing Record 35 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 4 | penzance
# Processing Record 37 of Set 4 | gazanjyk
# Processing Record 38 of Set 4 | pacific grove
# Processing Record 39 of Set 4 | kasongo-lunda
# Processing Record 40 of Set 4 | guajara-mirim
# City not found. Skipping...
# Processing Record 41 of Set 4 | baloda bazar
# Processing Record 42 of Set 4 | killybegs
# Processing Record 43 of Set 4 | hanzhong
# Processing Record 44 of Set 4 | bilibino
# Processing Record 45 of Set 4 | tiksi
# Processing Record 46 of Set 4 | inhambane
# Processing Record 47 of Set 4 | dasoguz
# Processing Record 48 of Set 4 | sembe
# Processing Record 49 of Set 4 | umm lajj
# Processing Record 50 of Set 4 | pangnirtung
# Processing Record 1 of Set 5 | souillac
# Processing Record 2 of Set 5 | taoudenni
# Processing Record 3 of Set 5 | avarua
# Processing Record 4 of Set 5 | vila velha
# Processing Record 5 of Set 5 | touros
# Processing Record 6 of Set 5 | borovoy
# Processing Record 7 of Set 5 | talaya
# Processing Record 8 of Set 5 | kaitangata
# Processing Record 9 of Set 5 | serik
# Processing Record 10 of Set 5 | marau
# Processing Record 11 of Set 5 | nanortalik
# Processing Record 12 of Set 5 | halifax
# Processing Record 13 of Set 5 | esperance
# Processing Record 14 of Set 5 | grand gaube
# Processing Record 15 of Set 5 | belluno
# Processing Record 16 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 5 | ericeira
# Processing Record 18 of Set 5 | miramar
# Processing Record 19 of Set 5 | sao filipe
# Processing Record 20 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 5 | ati
# Processing Record 22 of Set 5 | furano
# Processing Record 23 of Set 5 | lazaro cardenas
# Processing Record 24 of Set 5 | hobart
# Processing Record 25 of Set 5 | kuopio
# Processing Record 26 of Set 5 | lata
# Processing Record 27 of Set 5 | moiyabana
# City not found. Skipping...
# Processing Record 28 of Set 5 | kavieng
# Processing Record 29 of Set 5 | bambanglipuro
# Processing Record 30 of Set 5 | burns lake
# Processing Record 31 of Set 5 | yaqui
# Processing Record 32 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 5 | balakhta
# Processing Record 34 of Set 5 | andahuaylas
# Processing Record 35 of Set 5 | solnechnyy
# Processing Record 36 of Set 5 | essex
# Processing Record 37 of Set 5 | ruswil
# Processing Record 38 of Set 5 | hay river
# Processing Record 39 of Set 5 | sibolga
# Processing Record 40 of Set 5 | awbari
# Processing Record 41 of Set 5 | hecun
# Processing Record 42 of Set 5 | te anau
# Processing Record 43 of Set 5 | hualmay
# Processing Record 44 of Set 5 | namibe
# Processing Record 45 of Set 5 | ponta do sol
# Processing Record 46 of Set 5 | hami
# Processing Record 47 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 5 | flin flon
# Processing Record 49 of Set 5 | maceio
# Processing Record 50 of Set 5 | bozuyuk
# Processing Record 1 of Set 6 | buraydah
# Processing Record 2 of Set 6 | koutiala
# Processing Record 3 of Set 6 | tomioka
# Processing Record 4 of Set 6 | dunedin
# Processing Record 5 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 6 of Set 6 | bismarck
# Processing Record 7 of Set 6 | itarema
# Processing Record 8 of Set 6 | manggar
# Processing Record 9 of Set 6 | faanui
# Processing Record 10 of Set 6 | mayna
# Processing Record 11 of Set 6 | srandakan
# Processing Record 12 of Set 6 | tucuman
# Processing Record 13 of Set 6 | komsomolskiy
# Processing Record 14 of Set 6 | sinnamary
# Processing Record 15 of Set 6 | bria
# Processing Record 16 of Set 6 | weinan
# Processing Record 17 of Set 6 | berdigestyakh
# Processing Record 18 of Set 6 | preobrazheniye
# Processing Record 19 of Set 6 | imeni poliny osipenko
# Processing Record 20 of Set 6 | caransebes
# Processing Record 21 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 6 | baiyin
# Processing Record 23 of Set 6 | eenhana
# Processing Record 24 of Set 6 | rafai
# Processing Record 25 of Set 6 | sao joao da barra
# Processing Record 26 of Set 6 | shingu
# Processing Record 27 of Set 6 | nucsoara
# Processing Record 28 of Set 6 | okhotsk
# Processing Record 29 of Set 6 | puerto del rosario
# Processing Record 30 of Set 6 | ambon
# Processing Record 31 of Set 6 | quatre cocos
# Processing Record 32 of Set 6 | la ronge
# Processing Record 33 of Set 6 | santiago del estero
# Processing Record 34 of Set 6 | klaksvik
# Processing Record 35 of Set 6 | dabhol
# Processing Record 36 of Set 6 | coihaique
# Processing Record 37 of Set 6 | nabire
# Processing Record 38 of Set 6 | yenagoa
# Processing Record 39 of Set 6 | iskateley
# Processing Record 40 of Set 6 | piuma
# Processing Record 41 of Set 6 | orlik
# Processing Record 42 of Set 6 | pendleton
# Processing Record 43 of Set 6 | qui nhon
# Processing Record 44 of Set 6 | saint anthony
# Processing Record 45 of Set 6 | celina
# Processing Record 46 of Set 6 | gizo
# Processing Record 47 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 48 of Set 6 | mhlume
# Processing Record 49 of Set 6 | gat
# Processing Record 50 of Set 6 | warrington
# Processing Record 1 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 7 | champerico
# Processing Record 3 of Set 7 | chavakkad
# Processing Record 4 of Set 7 | dikson
# Processing Record 5 of Set 7 | ondorhaan
# City not found. Skipping...
# Processing Record 6 of Set 7 | baykit
# Processing Record 7 of Set 7 | mount isa
# Processing Record 8 of Set 7 | northam
# Processing Record 9 of Set 7 | huarmey
# Processing Record 10 of Set 7 | tuktoyaktuk
# Processing Record 11 of Set 7 | xinmin
# Processing Record 12 of Set 7 | laguna
# Processing Record 13 of Set 7 | chokurdakh
# Processing Record 14 of Set 7 | mahina
# Processing Record 15 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 16 of Set 7 | ketchikan
# Processing Record 17 of Set 7 | gananoque
# Processing Record 18 of Set 7 | hadejia
# Processing Record 19 of Set 7 | ravar
# Processing Record 20 of Set 7 | kattivakkam
# Processing Record 21 of Set 7 | akureyri
# Processing Record 22 of Set 7 | chauk
# Processing Record 23 of Set 7 | ancud
# Processing Record 24 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 7 | hofn
# Processing Record 26 of Set 7 | romny
# Processing Record 27 of Set 7 | itamaraju
# Processing Record 28 of Set 7 | stornoway
# Processing Record 29 of Set 7 | mangit
# Processing Record 30 of Set 7 | miandrivazo
# Processing Record 31 of Set 7 | comodoro rivadavia
# Processing Record 32 of Set 7 | marquette
# Processing Record 33 of Set 7 | alexander city
# Processing Record 34 of Set 7 | castro verde
# Processing Record 35 of Set 7 | kahului
# Processing Record 36 of Set 7 | lorengau
# Processing Record 37 of Set 7 | sterling
# Processing Record 38 of Set 7 | san cristobal
# Processing Record 39 of Set 7 | lasa
# Processing Record 40 of Set 7 | bengkulu
# Processing Record 41 of Set 7 | rocha
# Processing Record 42 of Set 7 | sioux lookout
# Processing Record 43 of Set 7 | matara
# Processing Record 44 of Set 7 | kenora
# Processing Record 45 of Set 7 | zempoala
# Processing Record 46 of Set 7 | bayir
# Processing Record 47 of Set 7 | doha
# Processing Record 48 of Set 7 | ahipara
# Processing Record 49 of Set 7 | burnie
# Processing Record 50 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 2 of Set 8 | saint-cesaire
# Processing Record 3 of Set 8 | diu
# Processing Record 4 of Set 8 | buta
# Processing Record 5 of Set 8 | iqaluit
# Processing Record 6 of Set 8 | saint-jerome
# Processing Record 7 of Set 8 | pundaguitan
# Processing Record 8 of Set 8 | aripuana
# Processing Record 9 of Set 8 | barrow
# Processing Record 10 of Set 8 | husavik
# Processing Record 11 of Set 8 | tigil
# Processing Record 12 of Set 8 | olgod
# Processing Record 13 of Set 8 | dunmore
# Processing Record 14 of Set 8 | port hedland
# Processing Record 15 of Set 8 | east stroudsburg
# Processing Record 16 of Set 8 | siauliai
# Processing Record 17 of Set 8 | syracuse
# Processing Record 18 of Set 8 | beaverlodge
# Processing Record 19 of Set 8 | eureka
# Processing Record 20 of Set 8 | vestmanna
# Processing Record 21 of Set 8 | marsh harbour
# Processing Record 22 of Set 8 | pumiao
# Processing Record 23 of Set 8 | biak
# Processing Record 24 of Set 8 | ponta delgada
# Processing Record 25 of Set 8 | the valley
# Processing Record 26 of Set 8 | karymskoye
# Processing Record 27 of Set 8 | waipawa
# Processing Record 28 of Set 8 | rudbar
# Processing Record 29 of Set 8 | tukrah
# Processing Record 30 of Set 8 | camargo
# Processing Record 31 of Set 8 | teeli
# Processing Record 32 of Set 8 | arkhangelskoye
# Processing Record 33 of Set 8 | sulphur springs
# Processing Record 34 of Set 8 | el alto
# Processing Record 35 of Set 8 | ocampo
# Processing Record 36 of Set 8 | carnarvon
# Processing Record 37 of Set 8 | karakol
# Processing Record 38 of Set 8 | manakara
# Processing Record 39 of Set 8 | rosetta
# Processing Record 40 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 41 of Set 8 | saint-pierre
# Processing Record 42 of Set 8 | sosnovo
# Processing Record 43 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 44 of Set 8 | poum
# Processing Record 45 of Set 8 | beyneu
# Processing Record 46 of Set 8 | joshimath
# Processing Record 47 of Set 8 | garowe
# Processing Record 48 of Set 8 | arroio grande
# Processing Record 49 of Set 8 | antalaha
# Processing Record 50 of Set 8 | coruripe
# Processing Record 1 of Set 9 | vardo
# Processing Record 2 of Set 9 | nuuk
# Processing Record 3 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 4 of Set 9 | usogorsk
# Processing Record 5 of Set 9 | puerto ayacucho
# Processing Record 6 of Set 9 | inirida
# Processing Record 7 of Set 9 | ulaangom
# Processing Record 8 of Set 9 | klyuchi
# Processing Record 9 of Set 9 | khagrachari
# City not found. Skipping...
# Processing Record 10 of Set 9 | manono
# Processing Record 11 of Set 9 | kalianget
# Processing Record 12 of Set 9 | tautira
# Processing Record 13 of Set 9 | krasnoarmeysk
# Processing Record 14 of Set 9 | anahuac
# Processing Record 15 of Set 9 | stephenville
# Processing Record 16 of Set 9 | barcelos
# Processing Record 17 of Set 9 | riverton
# Processing Record 18 of Set 9 | tongren
# Processing Record 19 of Set 9 | puerto madero
# Processing Record 20 of Set 9 | mattru
# Processing Record 21 of Set 9 | cao bang
# Processing Record 22 of Set 9 | fontenay-le-comte
# Processing Record 23 of Set 9 | vasai
# Processing Record 24 of Set 9 | vila
# Processing Record 25 of Set 9 | shache
# Processing Record 26 of Set 9 | ngara
# Processing Record 27 of Set 9 | chilakalurupet
# Processing Record 28 of Set 9 | launceston
# Processing Record 29 of Set 9 | the pas
# Processing Record 30 of Set 9 | acarau
# Processing Record 31 of Set 9 | candawaga
# City not found. Skipping...
# Processing Record 32 of Set 9 | mitsamiouli
# Processing Record 33 of Set 9 | rock sound
# Processing Record 34 of Set 9 | bac lieu
# Processing Record 35 of Set 9 | port augusta
# Processing Record 36 of Set 9 | kisangani
# Processing Record 37 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 9 | mwene-ditu
# Processing Record 39 of Set 9 | bogovarovo
# Processing Record 40 of Set 9 | maryville
# Processing Record 41 of Set 9 | nishihara
# Processing Record 42 of Set 9 | baracoa
# Processing Record 43 of Set 9 | aklavik
# Processing Record 44 of Set 9 | provideniya
# Processing Record 45 of Set 9 | nago
# Processing Record 46 of Set 9 | viedma
# Processing Record 47 of Set 9 | zilair
# Processing Record 48 of Set 9 | teguldet
# Processing Record 49 of Set 9 | arman
# Processing Record 50 of Set 9 | casper
# Processing Record 1 of Set 10 | kapoeta
# Processing Record 2 of Set 10 | pitimbu
# Processing Record 3 of Set 10 | uspenka
# Processing Record 4 of Set 10 | podgorenskiy
# Processing Record 5 of Set 10 | wladyslawowo
# Processing Record 6 of Set 10 | pathein
# Processing Record 7 of Set 10 | hue
# Processing Record 8 of Set 10 | bam
# Processing Record 9 of Set 10 | santiago de cao
# Processing Record 10 of Set 10 | toungoo
# City not found. Skipping...
# Processing Record 11 of Set 10 | ahuimanu
# Processing Record 12 of Set 10 | colac
# Processing Record 13 of Set 10 | todos santos
# Processing Record 14 of Set 10 | westport
# Processing Record 15 of Set 10 | huilong
# Processing Record 16 of Set 10 | asau
# Processing Record 17 of Set 10 | tuatapere
# Processing Record 18 of Set 10 | bairiki
# Processing Record 19 of Set 10 | arica
# Processing Record 20 of Set 10 | longyan
# Processing Record 21 of Set 10 | hirara
# Processing Record 22 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 23 of Set 10 | armacao dos buzios
# City not found. Skipping...
# Processing Record 24 of Set 10 | jinchang
# Processing Record 25 of Set 10 | krasnoselkup
# Processing Record 26 of Set 10 | mackay
# Processing Record 27 of Set 10 | grootfontein
# Processing Record 28 of Set 10 | tazovskiy
# Processing Record 29 of Set 10 | corrente
# Processing Record 30 of Set 10 | rapid city
# Processing Record 31 of Set 10 | upernavik
# Processing Record 32 of Set 10 | omboue
# Processing Record 33 of Set 10 | igarka
# Processing Record 34 of Set 10 | nouadhibou
# Processing Record 35 of Set 10 | guerrero negro
# Processing Record 36 of Set 10 | poceirao
# Processing Record 37 of Set 10 | lancaster
# Processing Record 38 of Set 10 | tanshui
# City not found. Skipping...
# Processing Record 39 of Set 10 | male
# Processing Record 40 of Set 10 | high level
# Processing Record 41 of Set 10 | benavente
# Processing Record 42 of Set 10 | hamilton
# Processing Record 43 of Set 10 | caravelas
# Processing Record 44 of Set 10 | sayyan
# Processing Record 45 of Set 10 | kitale
# Processing Record 46 of Set 10 | tura
# Processing Record 47 of Set 10 | vanimo
# Processing Record 48 of Set 10 | gornji milanovac
# Processing Record 49 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 10 | uyuni
# Processing Record 1 of Set 11 | alofi
# Processing Record 2 of Set 11 | ust-maya
# Processing Record 3 of Set 11 | ranong
# Processing Record 4 of Set 11 | bilma
# Processing Record 5 of Set 11 | vao
# Processing Record 6 of Set 11 | tondano
# Processing Record 7 of Set 11 | san felipe
# Processing Record 8 of Set 11 | jalu
# Processing Record 9 of Set 11 | evensk
# Processing Record 10 of Set 11 | lufkin
# Processing Record 11 of Set 11 | santa marta
# Processing Record 12 of Set 11 | los llanos de aridane
# Processing Record 13 of Set 11 | jiaojiang
# Processing Record 14 of Set 11 | sao paulo de olivenca
# Processing Record 15 of Set 11 | shiyan
# Processing Record 16 of Set 11 | gilgit
# Processing Record 17 of Set 11 | san jeronimo
# Processing Record 18 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 11 | abeche
# Processing Record 20 of Set 11 | tapiramuta
# Processing Record 21 of Set 11 | alta floresta
# Processing Record 22 of Set 11 | karachi
# Processing Record 23 of Set 11 | tahlequah
# Processing Record 24 of Set 11 | san rafael
# Processing Record 25 of Set 11 | homer
# Processing Record 26 of Set 11 | kaeo
# Processing Record 27 of Set 11 | santiago
# Processing Record 28 of Set 11 | yaring
# Processing Record 29 of Set 11 | sept-iles
# Processing Record 30 of Set 11 | grindavik
# Processing Record 31 of Set 11 | urusha
# Processing Record 32 of Set 11 | adamas
# Processing Record 33 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 11 | birjand
# Processing Record 35 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 11 | dabakala
# Processing Record 37 of Set 11 | priiskovyy
# Processing Record 38 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 39 of Set 11 | lavrentiya
# Processing Record 40 of Set 11 | devils lake
# Processing Record 41 of Set 11 | olafsvik
# Processing Record 42 of Set 11 | raga
# Processing Record 43 of Set 11 | praia
# Processing Record 44 of Set 11 | soyo
# Processing Record 45 of Set 11 | ushtobe
# Processing Record 46 of Set 11 | fort morgan
# Processing Record 47 of Set 11 | puerto escondido
# Processing Record 48 of Set 11 | kirakira
# Processing Record 49 of Set 11 | banjar
# Processing Record 50 of Set 11 | mount gambier
# Processing Record 1 of Set 12 | coquimbo
# Processing Record 2 of Set 12 | mareeba
# Processing Record 3 of Set 12 | rathkeale
# Processing Record 4 of Set 12 | entre rios
# Processing Record 5 of Set 12 | quang ngai
# Processing Record 6 of Set 12 | reforma
# Processing Record 7 of Set 12 | papetoai
# Processing Record 8 of Set 12 | goundam
# Processing Record 9 of Set 12 | rio gallegos
# Processing Record 10 of Set 12 | grafton
# Processing Record 11 of Set 12 | bonavista
# Processing Record 12 of Set 12 | najran
# Processing Record 13 of Set 12 | daud khel
# Processing Record 14 of Set 12 | sao felix do xingu
# Processing Record 15 of Set 12 | voh
# Processing Record 16 of Set 12 | brownsville
# Processing Record 17 of Set 12 | tavrichanka
# Processing Record 18 of Set 12 | kayes
# Processing Record 19 of Set 12 | jertih
# Processing Record 20 of Set 12 | camana
# Processing Record 21 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 12 | vrangel
# Processing Record 24 of Set 12 | tieli
# Processing Record 25 of Set 12 | berlevag
# Processing Record 26 of Set 12 | vangaindrano
# Processing Record 27 of Set 12 | altamira
# Processing Record 28 of Set 12 | barcelona
# Processing Record 29 of Set 12 | plettenberg bay
# Processing Record 30 of Set 12 | muskogee
# Processing Record 31 of Set 12 | kamsack
# Processing Record 32 of Set 12 | abu kamal
# Processing Record 33 of Set 12 | skibbereen
# Processing Record 34 of Set 12 | bighapur
# Processing Record 35 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 36 of Set 12 | inuvik
# Processing Record 37 of Set 12 | mlonggo
# Processing Record 38 of Set 12 | bida
# Processing Record 39 of Set 12 | funadhoo
# Processing Record 40 of Set 12 | seoul
# Processing Record 41 of Set 12 | codrington
# Processing Record 42 of Set 12 | pierre
# Processing Record 43 of Set 12 | naryan-mar
# Processing Record 44 of Set 12 | tahe
# Processing Record 45 of Set 12 | cockburn town
# Processing Record 46 of Set 12 | ossora
# Processing Record 47 of Set 12 | odweyne
# Processing Record 48 of Set 12 | mount pleasant
# Processing Record 49 of Set 12 | majene
# Processing Record 50 of Set 12 | ust-kuyga
# Processing Record 1 of Set 13 | urdoma
# Processing Record 2 of Set 13 | peleduy
# Processing Record 3 of Set 13 | shakawe
# Processing Record 4 of Set 13 | sicamous
# Processing Record 5 of Set 13 | jizan
# Processing Record 6 of Set 13 | nagorsk
# Processing Record 7 of Set 13 | russell
# Processing Record 8 of Set 13 | bacag
# Processing Record 9 of Set 13 | smirnykh
# Processing Record 10 of Set 13 | port pirie
# Processing Record 11 of Set 13 | platteville
# Processing Record 12 of Set 13 | verkhnyaya inta
# Processing Record 13 of Set 13 | lincoln
# Processing Record 14 of Set 13 | saldanha
# Processing Record 15 of Set 13 | vanavara
# Processing Record 16 of Set 13 | cromarty
# Processing Record 17 of Set 13 | greenville
# Processing Record 18 of Set 13 | nieuw amsterdam
# Processing Record 19 of Set 13 | novikovo
# Processing Record 20 of Set 13 | beloha
# Processing Record 21 of Set 13 | van
# Processing Record 22 of Set 13 | deputatskiy
# Processing Record 23 of Set 13 | vilhena
# Processing Record 24 of Set 13 | kharan
# Processing Record 25 of Set 13 | xinzhou
# Processing Record 26 of Set 13 | maldonado
# Processing Record 27 of Set 13 | zima
# Processing Record 28 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 13 | oum hadjer
# Processing Record 30 of Set 13 | villanueva
# Processing Record 31 of Set 13 | loikaw
# Processing Record 32 of Set 13 | vostok
# Processing Record 33 of Set 13 | srednekolymsk
# Processing Record 34 of Set 13 | mahon
# Processing Record 35 of Set 13 | soto la marina
# Processing Record 36 of Set 13 | casma
# Processing Record 37 of Set 13 | leh
# Processing Record 38 of Set 13 | raseiniai
# Processing Record 39 of Set 13 | auch
# Processing Record 40 of Set 13 | huangyan
# Processing Record 41 of Set 13 | nkhotakota
# Processing Record 42 of Set 13 | bonfim
# Processing Record 43 of Set 13 | darhan
# Processing Record 44 of Set 13 | codajas
# Processing Record 45 of Set 13 | tilichiki
# Processing Record 46 of Set 13 | florianopolis
# Processing Record 47 of Set 13 | kilmez
# City not found. Skipping...
# Processing Record 48 of Set 13 | shatrovo
# Processing Record 49 of Set 13 | horsham
# Processing Record 50 of Set 13 | burica
# City not found. Skipping...
# Processing Record 1 of Set 14 | dakar
# Processing Record 2 of Set 14 | nelson bay
# Processing Record 3 of Set 14 | jinji
# Processing Record 4 of Set 14 | cuiluan
# Processing Record 5 of Set 14 | havre-saint-pierre
# Processing Record 6 of Set 14 | luanda
# Processing Record 7 of Set 14 | bhabua
# Processing Record 8 of Set 14 | normal
# Processing Record 9 of Set 14 | iseyin
# Processing Record 10 of Set 14 | fairbanks
# Processing Record 11 of Set 14 | severo-yeniseyskiy
# Processing Record 12 of Set 14 | bemidji
# Processing Record 13 of Set 14 | tokonou
# Processing Record 14 of Set 14 | turukhansk
# Processing Record 15 of Set 14 | tiruchchendur
# Processing Record 16 of Set 14 | saint-joseph
# Processing Record 17 of Set 14 | nampa
# Processing Record 18 of Set 14 | santa ana
# Processing Record 19 of Set 14 | tual
# Processing Record 20 of Set 14 | wilkes-barre
# Processing Record 21 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 22 of Set 14 | khor
# Processing Record 23 of Set 14 | aranos
# Processing Record 24 of Set 14 | maralal
# Processing Record 25 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 14 | mbaiki
# Processing Record 27 of Set 14 | chodavaram
# Processing Record 28 of Set 14 | naze
# Processing Record 29 of Set 14 | bullhead city
# Processing Record 30 of Set 14 | chatellerault
# Processing Record 31 of Set 14 | diamantina
# Processing Record 32 of Set 14 | sheridan
# Processing Record 33 of Set 14 | saiha
# Processing Record 34 of Set 14 | capitan bado
# Processing Record 35 of Set 14 | znamenskoye
# Processing Record 36 of Set 14 | oshkosh
# Processing Record 37 of Set 14 | harrisonburg
# Processing Record 38 of Set 14 | jinka
# Processing Record 39 of Set 14 | whitehorse
# Processing Record 40 of Set 14 | nome
# Processing Record 41 of Set 14 | guatajiagua
# Processing Record 42 of Set 14 | palmer
# Processing Record 43 of Set 14 | snina
# Processing Record 44 of Set 14 | gorontalo
# Processing Record 45 of Set 14 | salinopolis
# Processing Record 46 of Set 14 | batagay-alyta
# Processing Record 47 of Set 14 | saint-louis
# Processing Record 48 of Set 14 | khovu-aksy
# Processing Record 49 of Set 14 | shangzhi
# Processing Record 50 of Set 14 | ostrovnoy
# Processing Record 1 of Set 15 | roma
# Processing Record 2 of Set 15 | abu samrah
# Processing Record 3 of Set 15 | mehamn
# Processing Record 4 of Set 15 | jijiga
# Processing Record 5 of Set 15 | mogok
# Processing Record 6 of Set 15 | varnamo
# Processing Record 7 of Set 15 | zabaykalsk
# Processing Record 8 of Set 15 | luderitz
# Processing Record 9 of Set 15 | baoying
# Processing Record 10 of Set 15 | hovd
# Processing Record 11 of Set 15 | gao
# Processing Record 12 of Set 15 | chama
# Processing Record 13 of Set 15 | talnakh
# Processing Record 14 of Set 15 | jumla
# Processing Record 15 of Set 15 | broken hill
# Processing Record 16 of Set 15 | umm kaddadah
# Processing Record 17 of Set 15 | yinchuan
# Processing Record 18 of Set 15 | vaitape
# Processing Record 19 of Set 15 | kirgiz-miyaki
# Processing Record 20 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 15 | plymouth
# Processing Record 22 of Set 15 | khash
# Processing Record 23 of Set 15 | tsalka
# Processing Record 24 of Set 15 | presidente medici
# Processing Record 25 of Set 15 | zhigansk
# Processing Record 26 of Set 15 | phra phutthabat
# Processing Record 27 of Set 15 | constitucion
# Processing Record 28 of Set 15 | chapais
# Processing Record 29 of Set 15 | ejura
# Processing Record 30 of Set 15 | koulikoro
# Processing Record 31 of Set 15 | jarjis
# City not found. Skipping...
# Processing Record 32 of Set 15 | mahajanga
# Processing Record 33 of Set 15 | voznesenskoye
# Processing Record 34 of Set 15 | bertoua
# Processing Record 35 of Set 15 | twin falls
# Processing Record 36 of Set 15 | obidos
# Processing Record 37 of Set 15 | caucaia
# Processing Record 38 of Set 15 | ankang
# Processing Record 39 of Set 15 | slave lake
# Processing Record 40 of Set 15 | kokstad
# Processing Record 41 of Set 15 | kindia
# Processing Record 42 of Set 15 | husum
# Processing Record 43 of Set 15 | damietta
# Processing Record 44 of Set 15 | aloleng
# Processing Record 45 of Set 15 | flinders
# Processing Record 46 of Set 15 | temiscaming
# Processing Record 47 of Set 15 | tunduru
# City not found. Skipping...
# Processing Record 48 of Set 15 | balkhash
# Processing Record 49 of Set 15 | takoradi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Bredasdorp      ZA -34.5322   20.0403     61.29        70          44
# 1         Ushuaia      AR -54.8000  -68.3000     42.46        81          40
# 2       Hithadhoo      MV  -0.6000   73.0833     81.61        74          67
# 3        Cidreira      BR -30.1811  -50.2056     71.33        83          60
# 4    Longyearbyen      SJ  78.2186   15.6401      8.44        72           0
# ..            ...     ...      ...       ...       ...       ...         ...
# 688       Aloleng      PH  16.1307  119.7824     82.42        58          26
# 689      Flinders      AU -34.5833  150.8552     72.18        56          84
# 690   Temiscaming      CA  46.7212  -79.0971     16.68        80         100
# 691      Balkhash      KZ  46.8440   74.9804      5.61        85          90
# 692      Takoradi      GH   4.8845   -1.7554     78.96        81          80
#
#      Wind Speed Current Description
# 0         12.17    scattered clouds
# 1         11.50    scattered clouds
# 2         10.56       broken clouds
# 3          7.07       broken clouds
# 4         11.50           clear sky
# ..          ...                 ...
# 688       11.21    scattered clouds
# 689        8.99       broken clouds
# 690        7.94     overcast clouds
# 691       13.42     overcast clouds
# 692        4.52          light rain
#
# [693 rows x 9 columns]

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label= "City_ID")
